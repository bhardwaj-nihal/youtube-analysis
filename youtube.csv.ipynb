# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
yt=pd.read_csv("most_subscribed_youtube_channels.csv")

# %%
yt
# Out:
#      rank                    Youtuber  subscribers   video views  video count  \
# 0       1                    T-Series    222000000  198459090822        17317
# 1       2              YouTube Movies    154000000             0            0
# 2       3  Cocomelon - Nursery Rhymes    140000000  135481339848          786
# 3       4                   SET India    139000000  125764252686        91271
# 4       5                       Music    116000000             0            0
# ..    ...                         ...          ...           ...          ...
# 995   996                    JP Plays     10900000    4609300218         3528
# 996   997               TrapMusicHDTV     10900000    4070521973          690
# 997   998                 Games EduUu     10900000    3093784767         1006
# 998   999                       Hueva     10900000    3040301750          831
# 999  1000              Dobre Brothers     10900000    2808411693          590
#
#              category  started
# ...

# %%
### checking for null value

# %%
yt.isnull().sum()
# Out:
# rank             0
# Youtuber         0
# subscribers      0
# video views      0
# video count      0
# category         0
# started          0
# blogging         0
# new              0
# month          999
# dtype: int64

# %%
### fill null value

# %%
yt['category'].fillna('undefined',inplace=True)

# %%
yt
# Out:
#      rank                    Youtuber  subscribers   video views  video count  \
# 0       1                    T-Series    222000000  198459090822        17317
# 1       2              YouTube Movies    154000000             0            0
# 2       3  Cocomelon - Nursery Rhymes    140000000  135481339848          786
# 3       4                   SET India    139000000  125764252686        91271
# 4       5                       Music    116000000             0            0
# ..    ...                         ...          ...           ...          ...
# 995   996                    JP Plays     10900000    4609300218         3528
# 996   997               TrapMusicHDTV     10900000    4070521973          690
# 997   998                 Games EduUu     10900000    3093784767         1006
# 998   999                       Hueva     10900000    3040301750          831
# 999  1000              Dobre Brothers     10900000    2808411693          590
#
#              category  started
# ...

# %%
yt['subscribers']
# Out:
# 0      222000000
# 1      154000000
# 2      140000000
# 3      139000000
# 4      116000000
#          ...
# 995     10900000
# 996     10900000
# 997     10900000
# 998     10900000
# 999     10900000
# Name: subscribers, Length: 1000, dtype: int64

# %%
yt
# Out:
#      rank                    Youtuber  subscribers   video views  video count  \
# 0       1                    T-Series    222000000  198459090822        17317
# 1       2              YouTube Movies    154000000             0            0
# 2       3  Cocomelon - Nursery Rhymes    140000000  135481339848          786
# 3       4                   SET India    139000000  125764252686        91271
# 4       5                       Music    116000000             0            0
# ..    ...                         ...          ...           ...          ...
# 995   996                    JP Plays     10900000    4609300218         3528
# 996   997               TrapMusicHDTV     10900000    4070521973          690
# 997   998                 Games EduUu     10900000    3093784767         1006
# 998   999                       Hueva     10900000    3040301750          831
# 999  1000              Dobre Brothers     10900000    2808411693          590
#
#              category  started
# ...

# %%
yt['started']
# Out:
# 0      2006
# 1      2015
# 2      2006
# 3      2006
# 4      2013
#        ...
# 995    2014
# 996    2013
# 997    2011
# 998    2012
# 999    2017
# Name: started, Length: 999, dtype: int64

# %%
### creating new columns

# %%
yt['blogging']=yt.sum()

# %%
yt
# Out:
#      rank                    Youtuber  subscribers   video views  video count  \
# 0       1                    T-Series    222000000  198459090822        17317
# 1       2              YouTube Movies    154000000             0            0
# 2       3  Cocomelon - Nursery Rhymes    140000000  135481339848          786
# 3       4                   SET India    139000000  125764252686        91271
# 4       5                       Music    116000000             0            0
# ..    ...                         ...          ...           ...          ...
# 995   996                    JP Plays     10900000    4609300218         3528
# 996   997               TrapMusicHDTV     10900000    4070521973          690
# 997   998                 Games EduUu     10900000    3093784767         1006
# 998   999                       Hueva     10900000    3040301750          831
# 999  1000              Dobre Brothers     10900000    2808411693          590
#
# ...

# %%
col=['subscribers','video views','video count','started']

# %%
yt['blogging'].fillna(yt[col].sum(axis=1),inplace=True)

# %%
yt
# Out:
#      rank                    Youtuber  subscribers   video views  video count  \
# 0       1                    T-Series    222000000  198459090822        17317
# 1       2              YouTube Movies    154000000             0            0
# 2       3  Cocomelon - Nursery Rhymes    140000000  135481339848          786
# 3       4                   SET India    139000000  125764252686        91271
# 4       5                       Music    116000000             0            0
# ..    ...                         ...          ...           ...          ...
# 995   996                    JP Plays     10900000    4609300218         3528
# 996   997               TrapMusicHDTV     10900000    4070521973          690
# 997   998                 Games EduUu     10900000    3093784767         1006
# 998   999                       Hueva     10900000    3040301750          831
# 999  1000              Dobre Brothers     10900000    2808411693          590
#
# ...

# %%
# which datatypes
yt.dtypes
# Out:
# rank            int64
# Youtuber       object
# subscribers     int64
# video views     int64
# video count     int64
# category       object
# started         int64
# blogging        int64
# new             int64
# month          object
# dtype: object

# %%
#### youtube have subscribers more than 12000000

# %%
yt[yt['subscribers']>12000000][['Youtuber','video count']]
# Out:
#                        Youtuber  video count
# 0                      T-Series        17317
# 1                YouTube Movies            0
# 2    Cocomelon - Nursery Rhymes          786
# 3                     SET India        91271
# 4                         Music            0
# ..                          ...          ...
# 819                    DeGoBooM         3062
# 820                        FIFA         9589
# 821                Más SKabeche          632
# 822                    Davie504          793
# 823                 Trakin Tech         3285
#
# [824 rows x 2 columns]

# %%
yt.loc[581]
# Out:
# rank                       582
# Youtuber          News18 India
# subscribers           14500000
# video views         5069817134
# video count             120858
# category       News & Politics
# started                   2007
# blogging            5084439999
# Name: 581, dtype: object

# %%
yt.tail(10)
# Out:
#      rank          Youtuber  subscribers  video views  video count  \
# 990   991         Viih Tube     11000000    886497694          505
# 991   992  OYUNCAKOYNUYORUM     10900000   9948474904          791
# 992   993         Brancoala     10900000   7934725886         1685
# 993   994    핑크퐁 (인기 동요・동화)     10900000   6663450148         2726
# 994   995              OGGY     10900000   5589104660          920
# 995   996          JP Plays     10900000   4609300218         3528
# 996   997     TrapMusicHDTV     10900000   4070521973          690
# 997   998       Games EduUu     10900000   3093784767         1006
# 998   999             Hueva     10900000   3040301750          831
# 999  1000    Dobre Brothers     10900000   2808411693          590
#
#              category  started    blogging
# 990    People & Blogs     2013   897500212
# 991     Entertainment     2016  9959377711
# 992     Entertainment     2008  7945629579
# 993         Education     2014  6674354888
# ...

# %%
yt
# Out:
#      rank                    Youtuber  subscribers   video views  video count  \
# 0       1                    T-Series    222000000  198459090822        17317
# 1       2              YouTube Movies    154000000             0            0
# 2       3  Cocomelon - Nursery Rhymes    140000000  135481339848          786
# 3       4                   SET India    139000000  125764252686        91271
# 4       5                       Music    116000000             0            0
# ..    ...                         ...          ...           ...          ...
# 995   996                    JP Plays     10900000    4609300218         3528
# 996   997               TrapMusicHDTV     10900000    4070521973          690
# 997   998                 Games EduUu     10900000    3093784767         1006
# 998   999                       Hueva     10900000    3040301750          831
# 999  1000              Dobre Brothers     10900000    2808411693          590
#
# ...

# %%
#### youtube channel have started year after 2010

# %%
yt[yt['started']>2010]['Youtuber']
# Out:
# 1         YouTube Movies
# 4                  Music
# 6                MrBeast
# 7      ✿ Kids Diana Show
# 8            Like Nastya
#              ...
# 995             JP Plays
# 996        TrapMusicHDTV
# 997          Games EduUu
# 998                Hueva
# 999       Dobre Brothers
# Name: Youtuber, Length: 705, dtype: object

# %%
### total youtube channel of gaming category

# %%
yt[yt['category']=='Gaming']['Youtuber']
# Out:
# 5          PewDiePie
# 43       JuegaGerman
# 47        Fernanfloo
# 59                A4
# 62       elrubiusOMG
#            ...
# 987    Coisa de Nerd
# 988        Taylor RS
# 995         JP Plays
# 997      Games EduUu
# 998            Hueva
# Name: Youtuber, Length: 102, dtype: object

# %%
yt
# Out:
#      rank                    Youtuber  subscribers   video views  video count  \
# 0       1                    T-Series    222000000  198459090822        17317
# 1       2              YouTube Movies    154000000             0            0
# 2       3  Cocomelon - Nursery Rhymes    140000000  135481339848          786
# 3       4                   SET India    139000000  125764252686        91271
# 4       5                       Music    116000000             0            0
# ..    ...                         ...          ...           ...          ...
# 995   996                    JP Plays     10900000    4609300218         3528
# 996   997               TrapMusicHDTV     10900000    4070521973          690
# 997   998                 Games EduUu     10900000    3093784767         1006
# 998   999                       Hueva     10900000    3040301750          831
# 999  1000              Dobre Brothers     10900000    2808411693          590
#
# ...

# %%
yt.max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of      rank                    Youtuber  subscribers   video views  video count  \
# 0       1                    T-Series    222000000  198459090822        17317
# 1       2              YouTube Movies    154000000             0            0
# 2       3  Cocomelon - Nursery Rhymes    140000000  135481339848          786
# 3       4                   SET India    139000000  125764252686        91271
# 4       5                       Music    116000000             0            0
# ..    ...                         ...          ...           ...          ...
# 995   996                    JP Plays     10900000    4609300218         3528
# 996   997               TrapMusicHDTV     10900000    4070521973          690
# 997   998                 Games EduUu     10900000    3093784767         1006
# 998   999                       Hueva     10900000    3040301750          831
# ...

# %%
df.max()
# Out:
#                        rank                               Youtuber  \
# category
# Autos & Vehicles        433                           DUDU e CAROL
# Comedy                  987                       whinderssonnunes
# Education               994                         핑크퐁 (인기 동요・동화)
# Entertainment           993                       ช่อง8 : Thai Ch8
# Film & Animation        995                         Маша и Медведь
# Gaming                  999  شبكة العاب العرب | Arab Games Network
# Howto & Style           976                             李子柒 Liziqi
# Movies                  303                    Ultra Movie Parlour
# Music                   997                    الـريماس - Al-Remas
# News & Politics         980                               Zee News
# Nonprofits & Activism   867                             TEDx Talks
# People & Blogs         1000                      웃웃TwinsFromRussia
# Pets & Animals          930                               The Dodo
# ...

# %%
df.describe()
# Out:
#                   0
# count  1.900000e+01
# mean   2.136837e+07
# std    6.185905e+06
# min    1.210000e+07
# 25%    1.746932e+07
# 50%    1.897563e+07
# 75%    2.368846e+07
# max    3.560000e+07

# %%
### adding 100 to video count

# %%
def sum(yt):
    yt=yt+100
    return yt

# %%
yt['video count'].apply(sum)
# Out:
# 0      17417
# 1        100
# 2        886
# 3      91371
# 4        100
#        ...
# 995     3628
# 996      790
# 997     1106
# 998      931
# 999      690
# Name: video count, Length: 1000, dtype: int64

# %%
yt
# Out:
#      rank                    Youtuber  subscribers   video views  video count  \
# 0       1                    T-Series    222000000  198459090822        17317
# 1       2              YouTube Movies    154000000             0            0
# 2       3  Cocomelon - Nursery Rhymes    140000000  135481339848          786
# 3       4                   SET India    139000000  125764252686        91271
# 4       5                       Music    116000000             0            0
# ..    ...                         ...          ...           ...          ...
# 995   996                    JP Plays     10900000    4609300218         3528
# 996   997               TrapMusicHDTV     10900000    4070521973          690
# 997   998                 Games EduUu     10900000    3093784767         1006
# 998   999                       Hueva     10900000    3040301750          831
# 999  1000              Dobre Brothers     10900000    2808411693          590
#
# ...

# %%
# yt['new']=yt.sum()

# %%
yt
# Out:
#      rank                    Youtuber  subscribers   video views  video count  \
# 0       1                    T-Series    222000000  198459090822        17317
# 1       2              YouTube Movies    154000000             0            0
# 2       3  Cocomelon - Nursery Rhymes    140000000  135481339848          786
# 3       4                   SET India    139000000  125764252686        91271
# 4       5                       Music    116000000             0            0
# ..    ...                         ...          ...           ...          ...
# 995   996                    JP Plays     10900000    4609300218         3528
# 996   997               TrapMusicHDTV     10900000    4070521973          690
# 997   998                 Games EduUu     10900000    3093784767         1006
# 998   999                       Hueva     10900000    3040301750          831
# 999  1000              Dobre Brothers     10900000    2808411693          590
#
# ...

# %%
### creating new column and fill with sum function

# %%
yt['new']=yt['video count'].apply(sum)

# %%
yt
# Out:
#      rank                    Youtuber  subscribers   video views  video count  \
# 0       1                    T-Series    222000000  198459090822        17317
# 1       2              YouTube Movies    154000000             0            0
# 2       3  Cocomelon - Nursery Rhymes    140000000  135481339848          786
# 3       4                   SET India    139000000  125764252686        91271
# 4       5                       Music    116000000             0            0
# ..    ...                         ...          ...           ...          ...
# 995   996                    JP Plays     10900000    4609300218         3528
# 996   997               TrapMusicHDTV     10900000    4070521973          690
# 997   998                 Games EduUu     10900000    3093784767         1006
# 998   999                       Hueva     10900000    3040301750          831
# 999  1000              Dobre Brothers     10900000    2808411693          590
#
# ...

# %%
yt
# Out:
#      rank                    Youtuber  subscribers   video views  video count  \
# 0       1                    T-Series    222000000  198459090822        17317
# 1       2              YouTube Movies    154000000             0            0
# 2       3  Cocomelon - Nursery Rhymes    140000000  135481339848          786
# 3       4                   SET India    139000000  125764252686        91271
# 4       5                       Music    116000000             0            0
# ..    ...                         ...          ...           ...          ...
# 995   996                    JP Plays     10900000    4609300218         3528
# 996   997               TrapMusicHDTV     10900000    4070521973          690
# 997   998                 Games EduUu     10900000    3093784767         1006
# 998   999                       Hueva     10900000    3040301750          831
# 999  1000              Dobre Brothers     10900000    2808411693          590
#
# ...

# %%
### creating new column

# %%
yt['month']=yt.sum()

# %%
yt
# Out:
#      rank                    Youtuber  subscribers   video views  video count  \
# 0       1                    T-Series    222000000  198459090822        17317
# 1       2              YouTube Movies    154000000             0            0
# 2       3  Cocomelon - Nursery Rhymes    140000000  135481339848          786
# 3       4                   SET India    139000000  125764252686        91271
# 4       5                       Music    116000000             0            0
# ..    ...                         ...          ...           ...          ...
# 995   996                    JP Plays     10900000    4609300218         3528
# 996   997               TrapMusicHDTV     10900000    4070521973          690
# 997   998                 Games EduUu     10900000    3093784767         1006
# 998   999                       Hueva     10900000    3040301750          831
# 999  1000              Dobre Brothers     10900000    2808411693          590
#
# ...

# %%
yt.drop(4)
# Out:
#      rank                    Youtuber  subscribers   video views  video count  \
# 0       1                    T-Series    222000000  198459090822        17317
# 1       2              YouTube Movies    154000000             0            0
# 2       3  Cocomelon - Nursery Rhymes    140000000  135481339848          786
# 3       4                   SET India    139000000  125764252686        91271
# 5       6                   PewDiePie    111000000   28469458228         4497
# ..    ...                         ...          ...           ...          ...
# 995   996                    JP Plays     10900000    4609300218         3528
# 996   997               TrapMusicHDTV     10900000    4070521973          690
# 997   998                 Games EduUu     10900000    3093784767         1006
# 998   999                       Hueva     10900000    3040301750          831
# 999  1000              Dobre Brothers     10900000    2808411693          590
#
# ...

# %%
yt
# Out:
#      rank                    Youtuber  subscribers   video views  video count  \
# 0       1                    T-Series    222000000  198459090822        17317
# 1       2              YouTube Movies    154000000             0            0
# 2       3  Cocomelon - Nursery Rhymes    140000000  135481339848          786
# 3       4                   SET India    139000000  125764252686        91271
# 4       5                       Music    116000000             0            0
# ..    ...                         ...          ...           ...          ...
# 995   996                    JP Plays     10900000    4609300218         3528
# 996   997               TrapMusicHDTV     10900000    4070521973          690
# 997   998                 Games EduUu     10900000    3093784767         1006
# 998   999                       Hueva     10900000    3040301750          831
# 999  1000              Dobre Brothers     10900000    2808411693          590
#
# ...

# %%
yt
# Out:
#      rank                    Youtuber  subscribers   video views  video count  \
# 0       1                    T-Series    222000000  198459090822        17317
# 1       2              YouTube Movies    154000000             0            0
# 2       3  Cocomelon - Nursery Rhymes    140000000  135481339848          786
# 3       4                   SET India    139000000  125764252686        91271
# 4       5                       Music    116000000             0            0
# ..    ...                         ...          ...           ...          ...
# 995   996                    JP Plays     10900000    4609300218         3528
# 996   997               TrapMusicHDTV     10900000    4070521973          690
# 997   998                 Games EduUu     10900000    3093784767         1006
# 998   999                       Hueva     10900000    3040301750          831
# 999  1000              Dobre Brothers     10900000    2808411693          590
#
# ...

# %%
yt2=pd.DataFrame(yt.head(10))

# %%
yt2
# Out:
#    rank                    Youtuber  subscribers   video views  video count  \
# 0     1                    T-Series    222000000  198459090822        17317
# 1     2              YouTube Movies    154000000             0            0
# 2     3  Cocomelon - Nursery Rhymes    140000000  135481339848          786
# 3     4                   SET India    139000000  125764252686        91271
# 4     5                       Music    116000000             0            0
# 5     6                   PewDiePie    111000000   28469458228         4497
# 6     7                     MrBeast    102000000   16832456681          726
# 7     8           ✿ Kids Diana Show     99700000   79602288245         1009
# 8     9                 Like Nastya     99200000   81963845811          702
# 9    10                      Gaming     92700000             0            0
#
#            category  started      blogging    new month
# 0             Music     2006  198681110145  17417   NaN
# ...

# %%
### line graph between youtubers and subscribers

# %%
plt.figure(figsize=(16,8))
plt.plot(yt2['Youtuber'],yt2['subscribers'],"r")
plt.xticks(rotation=90,fontsize=10)
plt.show()

# %%
### bar graph between youtubers and subscribers

# %%
plt.figure(figsize=(16,8))
plt.bar(yt2['Youtuber'],yt2['subscribers'])
plt.xticks(rotation=90,fontsize=10)
plt.show()

# %%
### scatter graph between youtubers and subscribers

# %%
plt.figure(figsize=(16,8))
plt.scatter(yt2['Youtuber'],yt2['subscribers'],color='#0008')
plt.xticks(rotation=90,fontsize=10)
plt.legend("a",loc=6)
plt.grid(True,color='r',linestyle=':')
plt.title('youtube',fontsize=100)
plt.show()

# %%
### line graph with marker

# %%
plt.figure(figsize=(16,8))
plt.plot(yt2['Youtuber'],yt2['subscribers'],color='#000008',marker='.',markersize=20)
plt.xticks(rotation=90,fontsize=10)
plt.legend("a",loc=6)
plt.grid(True,color='b',linestyle=':')
plt.title('youtube',fontsize=100)
plt.show()

# %%
yt
# Out:
#      rank                    Youtuber  subscribers   video views  video count  \
# 0       1                    T-Series    222000000  198459090822        17317
# 1       2              YouTube Movies    154000000             0            0
# 2       3  Cocomelon - Nursery Rhymes    140000000  135481339848          786
# 3       4                   SET India    139000000  125764252686        91271
# 4       5                       Music    116000000             0            0
# ..    ...                         ...          ...           ...          ...
# 995   996                    JP Plays     10900000    4609300218         3528
# 996   997               TrapMusicHDTV     10900000    4070521973          690
# 997   998                 Games EduUu     10900000    3093784767         1006
# 998   999                       Hueva     10900000    3040301750          831
# 999  1000              Dobre Brothers     10900000    2808411693          590
#
# ...

# %%
### channel of music category

# %%
yt[yt['category']=='Music']
# Out:
#      rank           Youtuber  subscribers   video views  video count category  \
# 0       1           T-Series    222000000  198459090822        17317    Music
# 11     12  Zee Music Company     86700000   49067711243         6603    Music
# 18     19          BANGTANTV     70000000   17471090750         1787    Music
# 19     20      Justin Bieber     69700000   28567240999          247    Music
# 20     21        HYBE LABELS     67800000   24013849120          971    Music
# ..    ...                ...          ...           ...          ...      ...
# 969   970             Genius     11100000    2891052624         2797    Music
# 982   983           Doja Cat     11000000    5459891400           25    Music
# 983   984               Tyga     11000000    5211071220          160    Music
# 989   990  unknown boy varun     11000000    3263285883          193    Music
# 996   997      TrapMusicHDTV     10900000    4070521973          690    Music
#
# ...

# %%
yt2.loc[6]
# Out:
# rank                       7
# Youtuber             MrBeast
# subscribers        102000000
# video views      16832456681
# video count              726
# category       Entertainment
# started                 2012
# blogging         16934459419
# new                      826
# month                    NaN
# Name: 6, dtype: object

# %%
#### details of mr beast youtube channel

# %%
yt[yt['Youtuber']=='MrBeast']
# Out:
#    rank Youtuber  subscribers  video views  video count       category  \
# 6     7  MrBeast    102000000  16832456681          726  Entertainment
#
#    started     blogging  new month
# 6     2012  16934459419  826   NaN

# %%
### channel whos rank in 100

# %%
yt[yt['rank']==100]
# Out:
# Empty DataFrame
# Columns: [rank, Youtuber, subscribers, video views, video count, category, started, blogging, new, month]
# Index: []

# %%
### channel started in 2016

# %%
yt[yt['started']==2016]
# Out:
#      rank           Youtuber  subscribers  video views  video count  \
# 8       9        Like Nastya     99200000  81963845811          702
# 13     14    5-Minute Crafts     77100000  23881457195         5581
# 14     15          BLACKPINK     76200000  24707415704          397
# 67     68          Voot Kids     38800000  17685426640         3282
# 76     77    Kimberly Loaiza     37200000   4254148920          206
# ..    ...                ...          ...          ...          ...
# 976   977   Virgínia Fonseca     11100000   1246793263         1047
# 984   985   Wolfoo's stories     11000000   4227479765          942
# 988   989          Taylor RS     11000000   3306502621         1845
# 989   990  unknown boy varun     11000000   3263285883          193
# 991   992   OYUNCAKOYNUYORUM     10900000   9948474904          791
#
#            category  started     blogging   new month
# 8    People & Blogs     2016  82063048529   802   NaN
# ...

# %%
yt.count()
# Out:
# rank           999
# Youtuber       999
# subscribers    999
# video views    999
# video count    999
# category       999
# started        999
# blogging       999
# new            999
# month            0
# dtype: int64

# %%
### total channels of every category

# %%
yt['category'].value_counts()
# Out:
# Entertainment            241
# Music                    222
# People & Blogs           119
# Gaming                   102
# Comedy                    63
# Film & Animation          52
# Education                 46
# Howto & Style             45
# undefined                 27
# News & Politics           27
# Science & Technology      18
# Shows                     14
# Sports                    10
# Pets & Animals             6
# Trailers                   2
# Nonprofits & Activism      2
# Movies                     2
# Autos & Vehicles           1
# Travel & Events            1
# Name: category, dtype: int64

# %%
yt
# Out:
#      rank                    Youtuber  subscribers   video views  video count  \
# 0       1                    T-Series    222000000  198459090822        17317
# 1       2              YouTube Movies    154000000             0            0
# 2       3  Cocomelon - Nursery Rhymes    140000000  135481339848          786
# 3       4                   SET India    139000000  125764252686        91271
# 4       5                       Music    116000000             0            0
# ..    ...                         ...          ...           ...          ...
# 995   996                    JP Plays     10900000    4609300218         3528
# 996   997               TrapMusicHDTV     10900000    4070521973          690
# 997   998                 Games EduUu     10900000    3093784767         1006
# 998   999                       Hueva     10900000    3040301750          831
# 999  1000              Dobre Brothers     10900000    2808411693          590
#
# ...

# %%
### toatl channel started yearwise

# %%
yt['started'].value_counts()
# Out:
# 2014    119
# 2011     93
# 2013     93
# 2015     93
# 2012     85
# 2016     77
# 2006     72
# 2009     63
# 2017     60
# 2010     47
# 2018     46
# 2008     45
# 2007     45
# 2019     25
# 2005     22
# 2020     10
# 2021      4
# Name: started, dtype: int64

# %%
yt[yt['started']==1970]
# Out:
#     rank Youtuber  subscribers  video views  video count         category  \
# 99   100  YouTube     33300000   2725286912          540  News & Politics
#
#     started    blogging  new month
# 99     1970  2758589422  640   NaN

# %%
yt.drop(99,inplace=True)

# %%
yt
# Out:
#      rank                    Youtuber  subscribers   video views  video count  \
# 0       1                    T-Series    222000000  198459090822        17317
# 1       2              YouTube Movies    154000000             0            0
# 2       3  Cocomelon - Nursery Rhymes    140000000  135481339848          786
# 3       4                   SET India    139000000  125764252686        91271
# 4       5                       Music    116000000             0            0
# ..    ...                         ...          ...           ...          ...
# 995   996                    JP Plays     10900000    4609300218         3528
# 996   997               TrapMusicHDTV     10900000    4070521973          690
# 997   998                 Games EduUu     10900000    3093784767         1006
# 998   999                       Hueva     10900000    3040301750          831
# 999  1000              Dobre Brothers     10900000    2808411693          590
#
# ...

# %%
## slicing

# %%
yt.loc[95:100]
# Out:
#      rank         Youtuber  subscribers  video views  video count  \
# 95     96        Mikecrack     33500000  13775632479         1727
# 96     97       VEGETTA777     33400000  14948682643         7130
# 97     98  Ultra Bollywood     33400000  15508274562         9078
# 98     99       Markiplier     33300000  18701808550         5200
# 100   101         ABP NEWS     33200000  10421462788       224455
#
#            category  started     blogging     new month
# 95           Gaming     2015  13809136221    1827   NaN
# 96           Gaming     2008  14982091781    7230   NaN
# 97         Trailers     2009  15541685649    9178   NaN
# 98           Gaming     2012  18735115762    5300   NaN
# 100  People & Blogs     2012  10454889255  224555   NaN

# %%
plt.figure(figsize=(16,8))
plt.plot(yt['category'].value_counts(),marker='.',markersize=20)
plt.xticks(rotation=90)
plt.show()

# %%
### display name of all categories

# %%
yt['category'].value_counts().index
# Out:
# Index(['Entertainment', 'Music', 'People & Blogs', 'Gaming', 'Comedy',
#        'Film & Animation', 'Education', 'Howto & Style', 'undefined',
#        'News & Politics', 'Science & Technology', 'Shows', 'Sports',
#        'Pets & Animals', 'Trailers', 'Nonprofits & Activism', 'Movies',
#        'Autos & Vehicles', 'Travel & Events'],
#       dtype='object')

# %%
yt['category'].value_counts().values
# Out:
# array([241, 222, 119, 102,  63,  52,  46,  45,  27,  26,  18,  14,  10,
#          6,   2,   2,   2,   1,   1], dtype=int64)

# %%
hutube=np.array([241, 222, 119, 102,  63,  52,  46,  45,  27,  26,  18])

# %%
### create pie chart of channel categories

# %%
labels=['Entertainment', 'Music', 'People & Blogs', 'Gaming', 'Comedy',
       'Film & Animation', 'Education', 'Howto & Style', 'undefined',
       'News & Politics', 'Science & Technology']
plt.axis('equal')
plt.pie(hutube,labels=labels,autopct='%1.1f%%')
plt.legend(loc=1)
plt.show()

# %%
### sum of video views of music category channels

# %%
yt[yt['category']=='Music']['video views'].sum()
# Out:
# 2906210355935

# %%
[yt['category'].value_counts()]
# Out:
# [Entertainment            241
#  Music                    222
#  People & Blogs           119
#  Gaming                   102
#  Comedy                    63
#  Film & Animation          52
#  Education                 46
#  Howto & Style             45
#  undefined                 27
#  News & Politics           26
#  Science & Technology      18
#  Shows                     14
#  Sports                    10
#  Pets & Animals             6
#  Trailers                   2
#  Nonprofits & Activism      2
#  Movies                     2
#  Autos & Vehicles           1
#  Travel & Events            1
#  Name: category, dtype: int64]

# %%
### mean of subscribers of education category

# %%
yt[yt['category']=='Education']['subscribers'].mean()
# Out:
# 23395652.173913043

# %%
#### mean of subscribers

# %%
ar=[yt[yt['category']=='Entertainment']['subscribers'].mean(),
yt[yt['category']=='Music']['subscribers'].mean(),
yt[yt['category']=='People & Blogs']['subscribers'].mean(),
yt[yt['category']=='Gaming']['subscribers'].mean(),
yt[yt['category']=='Comedy']['subscribers'].mean(),
yt[yt['category']=='Film & Animation']['subscribers'].mean(),
yt[yt['category']=='Education']['subscribers'].mean(),
yt[yt['category']=='Howto & Style']['subscribers'].mean(),
yt[yt['category']=='undefined']['subscribers'].mean(),
yt[yt['category']=='News & Politics']['subscribers'].mean(),
yt[yt['category']=='Science & Technology']['subscribers'].mean(),
yt[yt['category']=='Shows']['subscribers'].mean(),
yt[yt['category']=='Sports']['subscribers'].mean(),
yt[yt['category']=='Pets & Animals']['subscribers'].mean(),
yt[yt['category']=='Trailers']['subscribers'].mean(),
yt[yt['category']=='Nonprofits & Activism']['subscribers'].mean(),
yt[yt['category']=='Movies']['subscribers'].mean(),
yt[yt['category']=='Autos & Vehicles']['subscribers'].mean(),
yt[yt['category']=='Travel & Events']['subscribers'].mean()]

# %%
yt['category']
# Out:
# 0                 Music
# 1      Film & Animation
# 2             Education
# 3                 Shows
# 4             undefined
#              ...
# 995              Gaming
# 996               Music
# 997              Gaming
# 998              Gaming
# 999      People & Blogs
# Name: category, Length: 999, dtype: object

# %%
df=pd.DataFrame(ar)

# %%
df
# Out:
#                0
# 0   1.880871e+07
# 1   2.303739e+07
# 2   1.897563e+07
# 3   1.864510e+07
# 4   1.783968e+07
# 5   2.352692e+07
# 6   2.339565e+07
# 7   1.741556e+07
# 8   2.603333e+07
# 9   1.752308e+07
# 10  1.667222e+07
# 11  3.438571e+07
# 12  2.594000e+07
# 13  1.340000e+07
# 14  3.560000e+07
# 15  2.385000e+07
# 16  2.215000e+07
# 17  1.670000e+07
# 18  1.210000e+07

# %%
df.mean()
# Out:
# 0    2.136837e+07
# dtype: float64

# %%
yt['subscribers'].mean()
# Out:
# 20506606.606606606

# %%
plt.figure(figsize=(16,8))
plt.plot(yt['Youtuber'].head(10),yt['subscribers'].head(10),linestyle='dashed',marker='.',markersize='25',markerfacecolor='r',markeredgecolor='g')
plt.xticks(rotation=90)
plt.grid()
plt.legend('a',loc=1)
plt.xlabel('youtube',fontsize=20)
plt.ylabel('channel',fontsize=20)
plt.title('mohit saini',fontsize=20)
plt.show()
